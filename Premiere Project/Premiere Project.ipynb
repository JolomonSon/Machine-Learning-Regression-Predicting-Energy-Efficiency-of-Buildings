# %%
import pandas as pd
df = pd.read_csv('dataset/UK_Traffic_Accidents_2015.csv')
df.head(100)
# Out:
# C:\Users\ADEKANYE\AppData\Local\Temp\ipykernel_10592\3093188596.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset/UK_Traffic_Accidents_2015.csv')
#    Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0   201501BS70001               525130.0                180050.0  -0.198465
# 1   201501BS70002               526530.0                178560.0  -0.178838
# 2   201501BS70004               524610.0                181080.0  -0.205590
# 3   201501BS70005               524420.0                181080.0  -0.208327
# 4   201501BS70008               524630.0                179040.0  -0.206022
# ..            ...                    ...                     ...        ...
# 95  201501BS70115               524860.0                179170.0  -0.202664
# 96  201501BS70116               526910.0                177480.0  -0.173755
# ...
